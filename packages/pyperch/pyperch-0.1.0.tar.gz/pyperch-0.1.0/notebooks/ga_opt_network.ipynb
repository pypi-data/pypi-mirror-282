# %% [markdown]
# ## Skorch GA network classification example

# %%
import subprocess

# Installation on Google Colab
# !git clone https://github.com/jlm429/pyperch
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/pyperch')

try:
    import google.colab
    subprocess.run(['python', '-m', 'pip', 'install', 'skorch' , 'torch'])
except ImportError:
    pass

# %%
import numpy as np
from sklearn.datasets import make_classification
import torch
from torch import nn
from skorch import NeuralNetClassifier
from skorch import NeuralNet
from pyperch.neural.ga_nn import GAModule  
from pyperch.utils.decorators import add_to
from skorch.dataset import unpack_data
import copy
import matplotlib.pyplot as plt

# %%
X, y = make_classification(1000, 12, n_informative=10, random_state=0)
X = X.astype(np.float32)
y = y.astype(np.int64)

# %%
from skorch.callbacks import EpochScoring 

net = NeuralNetClassifier(
    module=GAModule,
    module__layer_sizes=(12, 32, 2),
    module__dropout_percent=(.01),
    module__activation=nn.Tanh(),
    module__population_size=300,
    module__to_mate=50,
    module__to_mutate=30,
    max_epochs=200,
    verbose=1,
    callbacks=[EpochScoring(scoring='accuracy', name='train_acc', on_train=True),],
    # use nn.CrossEntropyLoss instead of default nn.NLLLoss
    # for use with raw prediction values instead of log probabilities
    criterion=nn.CrossEntropyLoss(),
    # Shuffle training data on each epoch
    iterator_train__shuffle=True,
)

# %% [markdown]
# ## train_step_single override - add GA training step and disable backprop

# %%
#GAModule.register_ga_training_step()

# %%
# fit data
net.fit(X, y)
# Out:
# <class 'skorch.classifier.NeuralNetClassifier'>[initialized](
#   module_=GAModule(
#     (dropout): Dropout(p=0.05, inplace=False)
#     (activation): Tanh()
#     (output_activation): Softmax(dim=-1)
#     (layers): ModuleList(
#       (0): Linear(in_features=12, out_features=32, bias=True)
#       (1): Linear(in_features=32, out_features=2, bias=True)
#     )
#   ),
# )

# %% [markdown]
# ## Plot learning curves

# %%
# plot the iterative learning curve (loss)
plt.plot(net.history[:, 'train_loss'], label='Train Loss', color='navy')
plt.plot(net.history[:, 'valid_loss'], label='Validation Loss', color='lightcoral')
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.title("Iterative Learning Curve (Loss)")
plt.grid(visible=True)
plt.legend(frameon=False)

# %%
# plot the iterative learning curve (accuracy)
plt.plot(net.history[:, 'train_acc'], label='Train Acc', color='cornflowerblue')
plt.plot(net.history[:, 'valid_acc'], label='Validation Acc', color='chartreuse')
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.title("Iterative Learning Curve (Accuracy)")
plt.grid(visible=True)
plt.legend(frameon=False)

# %% [markdown]
# ## Using sklearn learning curve with RO

# %%
#### from sklearn.model_selection import learning_curve

# Plot the learning curve
train_sizes, train_scores, test_scores = learning_curve(
    net, X, y, train_sizes=np.linspace(0.1, 1.0, 5), cv=3
)

train_scores_mean = train_scores.mean(axis=1)
train_scores_std = train_scores.std(axis=1)
test_scores_mean = test_scores.mean(axis=1)
test_scores_std = test_scores.std(axis=1)
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color='cyan')
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color='darkorchid')
plt.plot(train_sizes, train_scores_mean, label="Training score", color='cyan')
plt.plot(train_sizes, test_scores_mean, label="Test score", color='darkorchid')
plt.title("Learning Curve")
plt.xlabel("Training size")
plt.ylabel("Score")
plt.grid(visible=True)
plt.legend(frameon=False)

# %% [markdown]
# ## Using sklearn pipeline with RO

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

pipe = Pipeline([
    ('scale', StandardScaler()),
    ('net', net),
])

pipe.fit(X, y)
y_proba = pipe.predict_proba(X)

# %% [markdown]
# ## Using sklearn grid search with RO

# %%
from sklearn.model_selection import GridSearchCV

# deactivate skorch-internal train-valid split and verbose logging
net.set_params(train_split=False, verbose=0, )

# module specific parameters need to begin with 'module__'
default_params = {
    'module__input_dim': [12],
    'module__output_dim': [2],
    #'max_epochs': [5],
    'module__population_size': [300],
    'module__to_mate': [150],
}

grid_search_params = {
    'module__to_mutate': [30, 60],
    'max_epochs': [5, 10, 15, 20],
    **default_params,
}

gs = GridSearchCV(net, grid_search_params, n_jobs=-1, refit=False, cv=3, scoring='accuracy', verbose=2)

gs.fit(X, y)
print("best score: {:.3f}, best params: {}".format(gs.best_score_, gs.best_params_))
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# [CV] END max_epochs=5, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time=  59.5s
# [CV] END max_epochs=5, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time=  59.0s
# [CV] END max_epochs=5, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time=  59.4s
# [CV] END max_epochs=5, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time=  59.9s
# [CV] END max_epochs=5, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time=  59.8s
# [CV] END max_epochs=5, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 1.0min
# [CV] END max_epochs=10, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 1.9min
# [CV] END max_epochs=10, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 2.0min
# [CV] END max_epochs=10, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 2.0min
# [CV] END max_epochs=10, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 2.0min
# [CV] END max_epochs=10, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 2.0min
# [CV] END max_epochs=10, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 2.0min
# [CV] END max_epochs=15, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 2.9min
# [CV] END max_epochs=15, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 3.0min
# [CV] END max_epochs=15, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 3.0min
# [CV] END max_epochs=15, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 3.0min
# best score: 0.625, best params: {'max_epochs': 20, 'module__input_dim': 12, 'module__output_dim': 2, 'module__population_size': 300, 'module__to_mate': 150, 'module__to_mutate': 30}
# [CV] END max_epochs=15, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 3.0min
# [CV] END max_epochs=15, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 3.1min
# [CV] END max_epochs=20, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 3.8min
# [CV] END max_epochs=20, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 3.8min
# [CV] END max_epochs=20, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=30; total time= 3.3min
# [CV] END max_epochs=20, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 3.4min
# [CV] END max_epochs=20, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 2.7min
# [CV] END max_epochs=20, module__input_dim=12, module__output_dim=2, module__population_size=300, module__to_mate=150, module__to_mutate=60; total time= 2.7min
