# %%
pip install --force multidimensional-wilcoxon-mann-whitney
# Out:
# Collecting multidimensional-wilcoxon-mann-whitney
#   Downloading multidimensional_wilcoxon_mann_whitney-0.0.1.post1-py3-none-any.whl.metadata (544 bytes)
# Downloading multidimensional_wilcoxon_mann_whitney-0.0.1.post1-py3-none-any.whl (2.1 kB)
# Installing collected packages: multidimensional-wilcoxon-mann-whitney
#   Attempting uninstall: multidimensional-wilcoxon-mann-whitney
#     Found existing installation: multidimensional-wilcoxon-mann-whitney 0.0.1
#     Uninstalling multidimensional-wilcoxon-mann-whitney-0.0.1:
#       Successfully uninstalled multidimensional-wilcoxon-mann-whitney-0.0.1
# Successfully installed multidimensional-wilcoxon-mann-whitney-0.0.1.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
from multidimensional_wilcoxon_mann_whitney import multidimensional_ranksum
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
n_samples = 1000
centers = [(-5, -5), (0, 0), (5, 5)]
X, y = make_blobs(n_samples=n_samples, centers=centers, shuffle=False, random_state=42)
y[-1]=0
plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.8, s=5)
plt.show()

argsorts, U =  multidimensional_ranksum(X)
plt.plot(argsorts[:,0])
plt.show()

plt.scatter(X[:, 0], X[:, 1], c=U, alpha=0.8, s=5)
plt.colorbar()
plt.show()
display(f"AvgU {np.mean(U)}");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       5 plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.8, s=5)
#       6 plt.show()
# ----> 8 argsorts, U =  multidimensional_ranksum(X)
#       9 plt.plot(argsorts[:,0])
#      10 plt.show()
#
# TypeError: 'module' object is not callable

# %%
n_samples = 1000
centers = [(-1,  0), (0, 0), (0, 1)]
X, y = make_blobs(n_samples=n_samples, centers=centers, shuffle=False, random_state=42)
plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.8, s=5)
plt.show()

argsorts, U =  multidimensional_ranksum(X)
plt.plot(argsorts[:,0])

plt.show()
plt.scatter(X[:, 0], X[:, 1], c=U, alpha=0.8, s=5)
plt.colorbar();

plt.show()
display(f"AvgU {np.mean(U)}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       4 plt.scatter(X[:, 0], X[:, 1], c=y, alpha=0.8, s=5)
#       5 plt.show()
# ----> 7 argsorts, U =  multidimensional_ranksum(X)
#       8 plt.plot(argsorts[:,0])
#      10 plt.show()
#
# TypeError: 'module' object is not callable
